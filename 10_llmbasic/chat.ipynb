# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# {'_request_id': 'req_0654f603db8d4553a6975cac34258ac7',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを使用する際のポイントはいくつかあります。以下に主要なポイントを挙げます：\n\n1. **目的の明確化**:\n   - 何を達成したいのかを明確にすることが重要です。情報の検索、テキスト生成、対話システムなど、目的に応じて適切な使い方を考えます。\n\n2. **入力データの品質**:\n   - 入力するテキストの質は出力の質に直結します。明確で具体的な質問や指示を与えることで、期待する結果を得やすくなります。\n\n3. **コンテキストの提供**:\n   - 文脈を正しく提供することで、モデルはより適切な応答を生成します。特に、前後の情報や具体的な状況を説明することが役立ちます。\n\n4. **フィードバックループの活用**:\n   - 得られた結果に対してフィードバックを行い、必要に応じて入力を調整することで、出力の質を向上させることができます。\n\n5. **モデルの理解**:\n   - 使用する言語モデルの特性（例えば、長文に対する応答の限界や知識の更新時期など）を理解することが重要です。これにより、誤解を避けることができます。\n\n6. **倫理的考慮**:\n   - 言語モデルを使用する際には、生成されるコンテンツの倫理的な側面を考慮する必要があります。偏見や誤情報が含まれる可能性があるため、慎重に評価し、必要であればチェックを行います。\n\n7. **カスタマイズの活用**:\n   - 特定の目的に合わせてモデルをチューニングしたり、特定のデータセットを用いて追加のトレーニングを行ったりすることで、よりパフォーマンスを向上させることが可能です。\n\n8. **使用制限の理解**:\n   - 法律やプライバシーに関する規制を遵守することが重要です。特に、個人情報やセンシティブな内容を扱う際には注意が必要です。\n\nこれらのポイントを考慮することで、言語モデルをより効果的に活用することができます。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))],
#  'created': 1771397979,
#  'id': 'chatcmpl-DAVp5lb2bqXCAw9qy0ZwXolB7jqA6',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_0773368f32',
#  'usage': CompletionUsage(completion_tokens=549, prompt_tokens=18, total_tokens=567, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}
# 言語モデルを使用する際のポイントはいくつかあります。以下に主要なポイントを挙げます：
#
# 1. **目的の明確化**:
#    - 何を達成したいのかを明確にすることが重要です。情報の検索、テキスト生成、対話システムなど、目的に応じて適切な使い方を考えます。
#
# 2. **入力データの品質**:
#    - 入力するテキストの質は出力の質に直結します。明確で具体的な質問や指示を与えることで、期待する結果を得やすくなります。
#
# 3. **コンテキストの提供**:
#    - 文脈を正しく提供することで、モデルはより適切な応答を生成します。特に、前後の情報や具体的な状況を説明することが役立ちます。
#
# 4. **フィードバックループの活用**:
#    - 得られた結果に対してフィードバックを行い、必要に応じて入力を調整することで、出力の質を向上させることができます。
#
# 5. **モデルの理解**:
#    - 使用する言語モデルの特性（例えば、長文に対する応答の限界や知識の更新時期など）を理解することが重要です。これにより、誤解を避けることができます。
#
# 6. **倫理的考慮**:
#    - 言語モデルを使用する際には、生成されるコンテンツの倫理的な側面を考慮する必要があります。偏見や誤情報が含まれる可能性があるため、慎重に評価し、必要であればチェックを行います。
#
# 7. **カスタマイズの活用**:
#    - 特定の目的に合わせてモデルをチューニングしたり、特定のデータセットを用いて追加のトレーニングを行ったりすることで、よりパフォーマンスを向上させることが可能です。
#
# 8. **使用制限の理解**:
#    - 法律やプライバシーに関する規制を遵守することが重要です。特に、個人情報やセンシティブな内容を扱う際には注意が必要です。
#
# これらのポイントを考慮することで、言語モデルをより効果的に活用することができます。

# %%
# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けた効果的なマーケティング戦略を以下に示します。これらのステップを通じて、製品の認知度を高め、顧客の興味を引き、販売を促進します。
#
# ### 1. ターゲット市場の特定
# - **市場調査**: 顧客のニーズ、競合状況、トレンドを分析して、ターゲット顧客を明確にします。
# - **ペルソナ作成**: ターゲットの典型的な顧客像を描き、そのニーズに応じたメッセージを検討します。
#
# ### 2. 価値提案の明確化
# - **製品のユニークな価値**: 新製品が他社製品とどう違うのか、顧客にどのような利点を提供するのかを明らかにします。
# - **メッセージング**: 明確で説得力のあるメッセージを作成します。
#
# ### 3. マーケティングミックスの活用
# - **4P（Product, Price, Place, Promotion）の戦略**:
#   - **製品（Product）**: 製品の特徴やデザインを強調し、サンプルやデモを提供します。
#   - **価格（Price）**: 初期の発売価格や特別キャンペーンを設定し、価格戦略を考慮します。
#   - **場所（Place）**: 新製品を販売するチャネルを選定し、オンラインとオフラインの両方で展開します。
#   - **プロモーション（Promotion）**: 広告、PR、SNS、インフルエンサーを活用したプロモーション戦略を立てます。
#
# ### 4. プロモーションプランの策定
# - **ティーザーキャンペーン**: 発売前に期待感を高めるためのティーザー広告を展開します。
# - **ローンチイベント**: 製品発表イベントを開催し、関係者やメディアを招待します。
# - **SNSキャンペーン**: インフルエンサーとのコラボや投稿キャンペーンを通じて認知度を上げる。
#
# ### 5. フィードバックループの構築
# - **顧客の声を活用**: フィードバックを受け取るためのチャネル（アンケート、SNSコメントなど）を設け、製品やサービスの改善につなげます。
# - **データ分析**: 販売データやマーケティング施策の効果を分析し、戦略を柔軟に調整します。
#
# ### 6. ロンチ後のアプローチ
# - **継続的なプロモーション**: 発売後もプロモーション活動を続け、顧客のリテンションにつなげます。
# - **リピート顧客の獲得**: ロイヤルティプログラムや特典を提供し、顧客の繰り返し購入を促します。
#
# これらの戦略を通じて、新製品の成功を最大化し、企業の成長をサポートします。

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=1.4,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本は独特の文化、歴史、美しい自然など、たくさんの魅力があります。以下にいくつかのポイントを紹介しますね。
#
# 1. **文化遺産**：
#    日本には多数のUNESCO世界遺産があり、古都京都や奈良の神社・仏閣、熊野古道、白川郷の合掌造り集落などがあります。これらは日本の
# --------------------
# もちろんです！日本は多様な魅力を持つ国で、風景、文化、食べ物、人々に至るまで、魅力的な要素がたくさんあります。
#
# ### 自然の美しさ
# 1. **山々と温泉**: 日本は美しい山々と穏やかな温泉地で知られています。特に富士山や四季折々の風景の名所がたくさん
# --------------------
# もちろん、日本の魅力は多岐にわたります。以下にいくつかのポイントをご紹介します。
#
# ### 1. 美しい自然
# - **季節の変化**: 日本は四季がはっきりしています。春には桜、夏には海や山、秋には紅葉、冬には雪景色が楽しめます。
# - **自然公園**: フィールドに美しい国立公園や温泉

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    presence_penalty=-2.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本は多様な魅力を持つ国で、文化、自然、食、歴史など様々な面で楽しむことができます。以下にいくつかの魅力を紹介します。
#
# ### 1. 文化と伝統
# 日本の文化は非常に豊かで、伝統と現代が融合しています。茶道、華道、書道などの伝統芸道は、心を落ち着け
# --------------------
# 日本はその独自の文化、歴史、自然、そして現代の技術の融合が魅力の国です。以下に日本の魅力をいくつか紹介します。
#
# ### 1. 文化と伝統
# - **祭りと行事**: 日本各地で行われる伝統的な祭り（例：祇園祭、ねぶた祭り）は、地元の文化を体験する絶好の
# --------------------
# もちろんです！日本は独自の文化、歴史、自然の美しさ、グルメなど、さまざまな魅力を持っています。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と歴史
# - **伝統的な芸能**：日本の伝統芸能である能や歌舞伎、茶道、花道などは、深い歴史と美しさを持

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=2
# tokens=[95839, 3393]

# %%
# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    logit_bias = {95839:8, 3393:8}
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B:こんにちは、Aさん！最近どうですか？
# --------------------
# B:こんにちは！Aさん、どうしていますか？
# --------------------
# B:こんにちは！Aさん、今日はどうしたの？

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを効果的に利用するためのポイントはいくつかあります。以下にいくつかの重要な点を挙げます。
#
# 1. **目的を明確にする**: 言語モデルをどのような目的で使用するのかを明確にしておくと、より効果的に活用できます。たとえば、文章生成、要約、翻訳、会話システムの構築など、目的によってアプローチが異なります。
#
# 2. **プロンプト設計**: モデルに渡すプロンプト（入力文）は、出力結果に大きな影響を与えます。明確で具体的な指示を含むプロンプトを設計することで、より望ましい結果を得やすくなります。
#
# 3. **コンテキストの提供**: モデルは文脈に依存して応答を生成するため、必要に応じて十分なコンテキストを提供することが重要です。関連情報や背景を含めると、より適切な応答が得られます。
#
# 4. **評価とフィードバック**: モデルの出力を評価し、必要に応じてフィードバックを与えることで、より優れた結果を引き出すことができます。特に繰り返し使用する場合は、改善点を洗い出すことが大切です。
#
# 5. **リミテーションを理解する**: 言語モデルには限界があります。例えば、知識の更新が行われない場合や、時事問題には対応できない場合があります。これを理解し、過信しないことが重要です。
#
# 6. **倫理的配慮**: モデルを使用する際には、偏見や誤情報の生成に対するリスクも考慮する必要があります。不適切なコンテンツを防ぐためのフィルタリングや監視を行うことが求められます。
#
# 7. **実験と学習**: 様々なプロンプトや設定で実験を行い、どのようなアプローチが最も効果的かを学ぶことが重要です。データやタスクに応じて柔軟に対応する姿勢が求められます。
#
# これらのポイントを考慮することで、言語モデルをより効果的に活用することができるでしょう。

# %%
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

# %%
for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを使用する際に考慮すべきポイントはいくつかあります。以下にいくつかの重要な点を挙げます。
#
# 1. **目的の明確化**: 何を達成したいのかを明確にしましょう。情報生成、質問応答、翻訳、要約など、使用目的によってモデルの設定や利用法が異なります。
#
# 2. **プロンプト設計**: モデルに与える入力（プロンプト）は非常に重要です。明確で具体的な指示を与えることで、より良い出力を得ることができます。
#
# 3. **フィードバックループ**: 応答を評価し、必要に応じて再プロンプトや修正を行うことで、出力の質を向上させることができます。
#
# 4. **バイアスの理解**: 言語モデルは訓練データに基づいており、バイアスが含まれる可能性があります。出力を使用する際には、そのバイアスを理解し、適切に対処する必要があります。
#
# 5. **倫理的考慮**: 言語モデルが生成するコンテンツには倫理的問題が伴うことがあります。出力が侮辱的、差別的、または誤解を招くものでないか常に確認する必要があります。
#
# 6. **利用可能なツールの把握**: 様々なAPIやライブラリが提供されているため、目的に応じた最適なツールを選ぶことも重要です。
#
# 7. **出力の検証**: モデルが生成した情報は必ずしも正確とは限らないため、特に重要な情報については必ず他の情報源と照らし合わせて確認します。
#
# 8. **コンテキストの管理**: モデルは通常、過去の対話や入力を考慮して応答を生成します。そのため、コンテキストを適切に管理することが必要です。
#
# これらのポイントを考慮することで、言語モデルをより効果的に活用することができます。
