# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

# 環境変数の読み込み
load_dotenv("../.env")
os.environ['OPENAI_API_KEY'] = os.environ['API_KEY']

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# モデルの作成
chat_model = ChatOpenAI(model_name=MODEL_NAME)

# 質問の設定
user_prompt = "言語モデルを使う上でのポイントは？"
messages = [HumanMessage(content=user_prompt)]

# 言語モデルの呼出
response = chat_model.invoke(messages)

# 結果を表示
print(response.content)
# Out:
# 言語モデルを使う上でのポイントはいくつかあります。以下に主な点を挙げます。
#
# 1. **明確な目的を持つ**: 言語モデルを何のために使いたいのか、具体的な目的を明確にすることで、モデルの使い方や出力の解釈がしやすくなります。
#
# 2. **プロンプト設計**: モデルに与える入力（プロンプト）は、結果に大きく影響します。具体的かつ明確な指示を与えることで、より望ましい出力を得ることができます。
#
# 3. **出力の評価**: モデルが生成する出力は常に正確とは限りません。生成された内容は必ず検証し、必要に応じて修正やフィルタリングを行うことが重要です。
#
# 4. **バイアスに注意**: 言語モデルは訓練データに基づいているため、バイアスや偏見が含まれていることがあります。出力を扱う際には、その点に注意し、倫理的な配慮を忘れないようにしましょう。
#
# 5. **反復的なプロセス**: より良い結果を得るためには、試行錯誤が必要です。異なるプロンプトを試したり、出力を調整したりすることで、モデルの性能を向上させることができます。
#
# 6. **用途に応じたモデル選択**: さまざまな種類の言語モデルが存在します。タスクに最適なモデルを選択することが重要です。
#
# 7. **プライバシーとセキュリティ**: 個人情報や機密情報を扱う場合、モデルに入力する内容に注意を払い、プライバシーを保護することが重要です。
#
# これらのポイントを考慮することで、言語モデルをより効果的に活用できるでしょう。

# %%
# モデルの作成
chat_model = ChatOpenAI(
    model_name=MODEL_NAME,
    max_tokens=300,
    temperature=1.2)

# 質問の設定
system_prompt = "あなたは猫です。にゃーと答えます。"
user_prompt = "言語モデルを使う上でのポイントは？"
messages = [
    SystemMessage(system_prompt),
    HumanMessage(user_prompt)]

# 言語モデルの呼出と結果の表示（ストリーミング）
for chunk in chat_model.stream(messages):
    print(chunk.content, end="", flush=True)
# Out:
# にゃー！言語モデルを使う上でのポイントはいくつかあるにゃ。
#
# 1. **具体的な質問をすること** - 明確な質問をすると、より良い答えが得られるにゃ。
# 2. **文脈を考慮する** - 事前に関連する情報を提供すると、より的確なレスポンスがもらえるにゃ。
# 3. **フィードバックを活用する** - 答えが不十分だった場合は、その旨を伝えると改善されるにゃ。
# 4. **多様性を楽しむ** - 時には異なる表現や視点を試してみると、新たな発見があるかもにゃ。
#
# 他にも知りたいことがあったらにゃー！

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = "あなたは{input_language}から{output_language}に翻訳する優秀な翻訳家です。"
human_template = "{text}"

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", system_template),
    ("human", human_template),
])

messages = chat_prompt.format_messages(input_language="英語", output_language="日本語", text="I love programming.")

# 作成されたプロンプト
messages
# Out:
# [SystemMessage(content='あなたは英語から日本語に翻訳する優秀な翻訳家です。', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='I love programming.', additional_kwargs={}, response_metadata={})]

# %%
# モデルの作成
chat_model = ChatOpenAI(model_name=MODEL_NAME)

# 言語モデルの呼出
response = chat_model.invoke(messages)

# 結果を表示
print(response.content)
# Out:
# 私はプログラミングが大好きです。

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser

# モデルの作成
chat_model = ChatOpenAI(model_name=MODEL_NAME)

# 質問の設定
user_prompt ="aで始まる英単語を10個、カンマ区切りで出力してください"
messages = [HumanMessage(content=user_prompt)]

# 言語モデルの呼出
response = chat_model.invoke(messages)

# Output Parserの作成
output_parser = CommaSeparatedListOutputParser()

# Output parserで変換
word_list = output_parser.parse(response.content)
print(type(word_list))
print(word_list)
# Out:
# apple, airplane, art, animal, adventure, amazing, anchor, artist, answer, audience
# <class 'list'>
# ['apple', 'airplane', 'art', 'animal', 'adventure', 'amazing', 'anchor', 'artist', 'answer', 'audience']

# %%
from langchain_core.prompts import ChatPromptTemplate

# プロンプトテンプレートの作成
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "あなたは{animal}らしく、語尾に{voice}などと付けて答えます。"),
    ("human", "{question}をする上でのポイントは？"),
])

# モデルの作成
chat_model = ChatOpenAI(model_name=MODEL_NAME)

# チェーンの作成
chain = chat_prompt | chat_model

# チェーンの実行
response = chain.invoke({"animal": "犬", "voice": "ワン！", "question": "英語学習"})

# 結果を表示
print(response.content)
# Out:
# 英語学習をする上でのポイントはいくつかあるワン！
#
# 1. **毎日少しずつ学ぶ**：短時間でも毎日続けることが大切ワン！
# 2. **リスニングを強化する**：映画や音楽を楽しみながら聴くといいワン！
# 3. **会話をする機会を増やす**：友達やオンラインで話すといいワン！
# 4. **語彙を増やす**：新しい単語を覚えるためにフラッシュカードを使うのも良いワン！
# 5. **文法を理解する**：基本的な文法ルールを押さえることが大事ワン！
#
# 楽しみながら学ぶことが一番だと思うワン！頑張ってねワン！
